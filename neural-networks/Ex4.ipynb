# %% [markdown]
# # Section a)

# %% [markdown]
# ## (1): f(x) = 1/x (1 <= x <= 100)

# %%
import torch
import torch.nn as nn
import numpy as np

SEED = 5218
np.random.seed(SEED)
torch.manual_seed(SEED)


def main(number_of_neurons):
    print(f'Running for NN with', number_of_neurons, 'hidden neurons', )
    # Defining input size, hidden layer size, output size and batch size respectively
    n_in, n_h, n_out, batch_size = 1, number_of_neurons, 1, 1000

    x_raw = 99 * np.random.rand(batch_size, n_in) + 1

    # Create training data
    x = torch.FloatTensor(x_raw[:800])
    y = torch.FloatTensor(1 / x_raw[:800])

    # Create test data
    x_test = torch.FloatTensor(x_raw[800:])
    y_test = torch.FloatTensor(1 / x_raw[800:])

    # Create the first model
    model = nn.Sequential(nn.Linear(n_in, n_h),
                          nn.Sigmoid(),
                          nn.Linear(n_h, n_out),
                          nn.Sigmoid())

    # Construct the loss function
    criterion = torch.nn.MSELoss()

    # Construct the optimizer (Stochastic Gradient Descent in this case)
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

    # Gradient Descent
    for epoch in range(10):
        # Forward pass: Compute predicted y by passing x to the model
        y_pred = model(x)

        # Compute and print loss
        loss = criterion(y_pred, y)
        # print('epoch: ', epoch, ' loss: ', loss.item())

        # Zero gradients, perform a backward pass, and update the weights.
        optimizer.zero_grad()

        # perform a backward pass (backpropagation)
        loss.backward()

        # Update the parameters
        optimizer.step()

    y_pred_test = model(x_test)
    test_loss = criterion(y_pred_test, y_test)
    print('Train loss: ', loss.item())
    print('Test loss : ', test_loss.item())


for x in range(1, 10):
    main(x)
# Out:
# Running for NN with 1 hidden neurons
# Train loss:  0.11538510769605637
# Test loss :  0.11599326878786087
# Running for NN with 2 hidden neurons
# Train loss:  0.14410904049873352
# Test loss :  0.14534837007522583
# Running for NN with 3 hidden neurons
# Train loss:  0.3062540590763092
# Test loss :  0.30472204089164734
# Running for NN with 4 hidden neurons
# Train loss:  0.09828854352235794
# Test loss :  0.09675116091966629
# Running for NN with 5 hidden neurons
# Train loss:  0.3077518939971924
# Test loss :  0.3039567470550537
# Running for NN with 6 hidden neurons
# Train loss:  0.09848813712596893
# Test loss :  0.09962539374828339
# Running for NN with 7 hidden neurons
# Train loss:  0.2257748693227768
# Test loss :  0.22452621161937714
# Running for NN with 8 hidden neurons
# Train loss:  0.2157893031835556
# Test loss :  0.21090544760227203
# Running for NN with 9 hidden neurons
# Train loss:  0.17677071690559387
# Test loss :  0.17435728013515472

# %% [markdown]
# ## (2): f(x) = log_10(x) (1 <= x <= 10)

# %%
import torch
import torch.nn as nn
import numpy as np

SEED = 5218
np.random.seed(SEED)
torch.manual_seed(SEED)


def main(number_of_neurons):
    print(f'Running for NN with', number_of_neurons, 'hidden neurons', )
    # Defining input size, hidden layer size, output size and batch size respectively
    n_in, n_h, n_out, batch_size = 1, number_of_neurons, 1, 1000

    x_raw = 99 * np.random.rand(batch_size, n_in) + 1

    # Create training data
    x = torch.FloatTensor(x_raw[:800])
    y = torch.FloatTensor(np.log10(x_raw[:800]))

    # Create test data
    x_test = torch.FloatTensor(x_raw[800:])
    y_test = torch.FloatTensor(np.log10(x_raw[800:]))

    # Create the first model
    model = nn.Sequential(nn.Linear(n_in, n_h),
                          nn.Sigmoid(),
                          nn.Linear(n_h, n_out),
                          nn.Sigmoid())

    # Construct the loss function
    criterion = torch.nn.MSELoss()

    # Construct the optimizer (Stochastic Gradient Descent in this case)
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

    # Gradient Descent
    for epoch in range(50):
        # Forward pass: Compute predicted y by passing x to the model
        y_pred = model(x)

        # Compute and print loss
        loss = criterion(y_pred, y)
        # print('epoch: ', epoch, ' loss: ', loss.item())

        # Zero gradients, perform a backward pass, and update the weights.
        optimizer.zero_grad()

        # perform a backward pass (backpropagation)
        loss.backward()

        # Update the parameters
        optimizer.step()

    y_pred_test = model(x_test)
    test_loss = criterion(y_pred_test, y_test)

    print('Train loss: ', loss.item())
    print('Test loss : ', test_loss.item())


for x in range(1, 10):
    main(x)
# Out:
# Running for NN with 1 hidden neurons
# Train loss:  2.6985466480255127
# Test loss :  2.7925519943237305
# Running for NN with 2 hidden neurons
# Train loss:  2.655785083770752
# Test loss :  2.7496211528778076
# Running for NN with 3 hidden neurons
# Train loss:  2.6575937271118164
# Test loss :  2.6412205696105957
# Running for NN with 4 hidden neurons
# Train loss:  2.6429190635681152
# Test loss :  2.686903476715088
# Running for NN with 5 hidden neurons
# Train loss:  2.733041763305664
# Test loss :  2.7241005897521973
# Running for NN with 6 hidden neurons
# Train loss:  2.6419661045074463
# Test loss :  2.730255126953125
# Running for NN with 7 hidden neurons
# Train loss:  2.6531455516815186
# Test loss :  2.6716458797454834
# Running for NN with 8 hidden neurons
# Train loss:  2.645585298538208
# Test loss :  2.6039960384368896
# Running for NN with 9 hidden neurons
# Train loss:  2.6407928466796875
# Test loss :  2.613058090209961

# %% [markdown]
# ## (3): f(x) = exp(-x) (1 <= x <= 10)

# %%
import torch
import torch.nn as nn
import numpy as np

SEED = 5218
np.random.seed(SEED)
torch.manual_seed(SEED)


def main(number_of_neurons):
    print(f'Running for NN with', number_of_neurons, 'hidden neurons', )
    # Defining input size, hidden layer size, output size and batch size respectively
    n_in, n_h, n_out, batch_size = 1, number_of_neurons, 1, 1000

    x_raw = 99 * np.random.rand(batch_size, n_in) + 1

    # Create training data
    x = torch.FloatTensor(x_raw[:800])
    y = torch.FloatTensor(np.exp(-x_raw[:800]))

    # Create test data
    x_test = torch.FloatTensor(x_raw[800:])
    y_test = torch.FloatTensor(np.exp(-x_raw[800:]))

    # Create the first model
    model = nn.Sequential(nn.Linear(n_in, n_h),
                          nn.Sigmoid(),
                          nn.Linear(n_h, n_out),
                          nn.Sigmoid())

    # Construct the loss function
    criterion = torch.nn.MSELoss()

    # Construct the optimizer (Stochastic Gradient Descent in this case)
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

    # Gradient Descent
    for epoch in range(50):
        # Forward pass: Compute predicted y by passing x to the model
        y_pred = model(x)

        # Compute and print loss
        loss = criterion(y_pred, y)
        # print('epoch: ', epoch, ' loss: ', loss.item())

        # Zero gradients, perform a backward pass, and update the weights.
        optimizer.zero_grad()

        # perform a backward pass (backpropagation)
        loss.backward()

        # Update the parameters
        optimizer.step()

    y_pred_test = model(x_test)
    test_loss = criterion(y_pred_test, y_test)

    print('Train loss: ', loss.item())
    print('Test loss : ', test_loss.item())


for x in range(1, 10):
    main(x)
# Out:
# Running for NN with 1 hidden neurons
# Train loss:  0.11625634878873825
# Test loss :  0.11658844351768494
# Running for NN with 2 hidden neurons
# Train loss:  0.1407928615808487
# Test loss :  0.14142820239067078
# Running for NN with 3 hidden neurons
# Train loss:  0.28573527932167053
# Test loss :  0.28552669286727905
# Running for NN with 4 hidden neurons
# Train loss:  0.08932240307331085
# Test loss :  0.08926607668399811
# Running for NN with 5 hidden neurons
# Train loss:  0.212184339761734
# Test loss :  0.21037940680980682
# Running for NN with 6 hidden neurons
# Train loss:  0.09339664876461029
# Test loss :  0.09362932294607162
# Running for NN with 7 hidden neurons
# Train loss:  0.1490449458360672
# Test loss :  0.14823968708515167
# Running for NN with 8 hidden neurons
# Train loss:  0.1428530067205429
# Test loss :  0.14029115438461304
# Running for NN with 9 hidden neurons
# Train loss:  0.13246232271194458
# Test loss :  0.13114768266677856

# %% [markdown]
# ## (4): f(x) =sin(x) (1 <= x <= 10)

# %%
import torch
import torch.nn as nn
import numpy as np

SEED = 5218
np.random.seed(SEED)
torch.manual_seed(SEED)


def main(number_of_neurons):
    print(f'Running for NN with', number_of_neurons, 'hidden neurons', )
    # Defining input size, hidden layer size, output size and batch size respectively
    n_in, n_h, n_out, batch_size = 1, number_of_neurons, 1, 1000

    x_raw = np.pi / 2 * np.random.rand(batch_size, n_in)

    # Create training data
    x = torch.FloatTensor(x_raw[:800])
    y = torch.FloatTensor(np.sin(x_raw[:800]))

    # Create test data
    x_test = torch.FloatTensor(x_raw[800:])
    y_test = torch.FloatTensor(np.sin(x_raw[800:]))

    # Create the first model
    model = nn.Sequential(nn.Linear(n_in, n_h),
                          nn.Sigmoid(),
                          nn.Linear(n_h, n_out),
                          nn.Sigmoid())

    # Construct the loss function
    criterion = torch.nn.MSELoss()

    # Construct the optimizer (Stochastic Gradient Descent in this case)
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

    # Gradient Descent
    for epoch in range(50):
        # Forward pass: Compute predicted y by passing x to the model
        y_pred = model(x)

        # Compute and print loss
        loss = criterion(y_pred, y)
        # print('epoch: ', epoch, ' loss: ', loss.item())

        # Zero gradients, perform a backward pass, and update the weights.
        optimizer.zero_grad()

        # perform a backward pass (backpropagation)
        loss.backward()

        # Update the parameters
        optimizer.step()

    y_pred_test = model(x_test)
    test_loss = criterion(y_pred_test, y_test)

    print('Train loss: ', loss.item())
    print('Test loss : ', test_loss.item())


for x in range(1, 10):
    main(x)
# Out:
# Running for NN with 1 hidden neurons
# Train loss:  0.1565742790699005
# Test loss :  0.17354196310043335
# Running for NN with 2 hidden neurons
# Train loss:  0.1279725283384323
# Test loss :  0.13148704171180725
# Running for NN with 3 hidden neurons
# Train loss:  0.09516369551420212
# Test loss :  0.09618625044822693
# Running for NN with 4 hidden neurons
# Train loss:  0.14285480976104736
# Test loss :  0.153558149933815
# Running for NN with 5 hidden neurons
# Train loss:  0.08525662124156952
# Test loss :  0.08974616974592209
# Running for NN with 6 hidden neurons
# Train loss:  0.14617902040481567
# Test loss :  0.1482691466808319
# Running for NN with 7 hidden neurons
# Train loss:  0.10187367349863052
# Test loss :  0.10125637799501419
# Running for NN with 8 hidden neurons
# Train loss:  0.09795249998569489
# Test loss :  0.1071053072810173
# Running for NN with 9 hidden neurons
# Train loss:  0.10585307329893112
# Test loss :  0.10709894448518753

# %% [markdown]
# # Section b) f(x) =sin(x)cos(y) (-pi/2 <= x <= pi/2; -pi/2 <= y <= pi/2)

# %%
import torch
import torch.nn as nn
import numpy as np
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot
from matplotlib import cm

SEED = 5218
np.random.seed(SEED)
torch.manual_seed(SEED)
TEST_DATA_RATIO = 0.8


def test_divider(batch_size):
    return int(TEST_DATA_RATIO * batch_size)


def main(number_of_neurons):
    print(f'Running for NN with', number_of_neurons, 'hidden neurons', )
    # Defining input size, hidden layer size, output size and batch size respectively
    n_in, n_h, n_out, batch_size = 2, number_of_neurons, 1, 1000

    x_raw = np.pi * np.random.rand(batch_size, n_in) - np.pi / 2
    # y_raw = np.pi * np.random.rand(batch_size, n_in) - np.pi/2

    # Create training data
    x = torch.FloatTensor(x_raw[:test_divider(batch_size)])
    f = torch.FloatTensor(np.reshape(np.multiply(np.sin(x_raw[:test_divider(batch_size), 0]),
                                                 np.cos(x_raw[:test_divider(batch_size), 1])),
                                     (test_divider(batch_size), 1)))

    # Create test data
    x_test = torch.FloatTensor(x_raw[test_divider(batch_size):])
    f_test = torch.FloatTensor(np.reshape(np.multiply(np.sin(x_raw[test_divider(batch_size):, 0]),
                                                      np.cos(x_raw[test_divider(batch_size):, 1])),
                                          (batch_size - test_divider(batch_size), 1)))

    # Create the first model
    model = nn.Sequential(nn.Linear(n_in, n_h),
                          nn.Sigmoid(),
                          nn.Linear(n_h, n_out),
                          nn.Sigmoid())

    # Construct the loss function
    criterion = torch.nn.MSELoss()

    # Construct the optimizer (Stochastic Gradient Descent in this case)
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

    # Gradient Descent
    for epoch in range(500):
        # Forward pass: Compute predicted y by passing x to the model
        f_pred = model(x)

        # Compute and print loss
        loss = criterion(f_pred, f)
        # print('epoch: ', epoch, ' loss: ', loss.item())

        # Zero gradients, perform a backward pass, and update the weights.
        optimizer.zero_grad()

        # perform a backward pass (backpropagation)
        loss.backward()

        # Update the parameters
        optimizer.step()

    f_pred_test = model(x_test)
    test_loss = criterion(f_pred_test, f_test)

    print('Train loss: ', loss.item())
    print('Test loss : ', test_loss.item())
    fig = pyplot.figure()
    ax = fig.gca(projection='3d')

    x_draw, y_draw = np.meshgrid(x_raw[test_divider(batch_size):, 0],
                                 x_raw[test_divider(batch_size):, 1])
    z_draw_pred = f_pred.detach().numpy()
    z_draw_test = np.multiply(np.sin(x_draw), np.cos(y_draw))
    surf_pred = ax.scatter(x_raw[:test_divider(batch_size), 0], x_raw[:test_divider(batch_size), 1], z_draw_pred, c='b', marker='^')
    surf_test = ax.plot_surface(x_draw, y_draw, z_draw_test, cmap=cm.seismic,
                                 linewidth=0, antialiased=False)

    # Customize the z axis.
    ax.set_zlim(-1.01, 1.01)
    ax.zaxis.set_major_locator(LinearLocator(20))
    ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
    pyplot.show()


for x in range(10, 20):
    main(x)
# Out:
# Running for NN with 10 hidden neurons
# Train loss:  0.2558549642562866
# Test loss :  0.2645411193370819
# Running for NN with 11 hidden neurons
# Train loss:  0.2679758071899414
# Test loss :  0.24963918328285217
# Running for NN with 12 hidden neurons
# Train loss:  0.27773115038871765
# Test loss :  0.2231159806251526
# Running for NN with 13 hidden neurons
# Train loss:  0.27305346727371216
# Test loss :  0.3061748445034027
# Running for NN with 14 hidden neurons
# Train loss:  0.24120604991912842
# Test loss :  0.27608343958854675
# Running for NN with 15 hidden neurons
# Train loss:  0.24807040393352509
# Test loss :  0.20829425752162933
# Running for NN with 16 hidden neurons
# Train loss:  0.25853225588798523
# Test loss :  0.2388351559638977
# Running for NN with 17 hidden neurons
# Train loss:  0.2621261477470398
# Test loss :  0.2886195182800293
# Running for NN with 18 hidden neurons
# Train loss:  0.2553647458553314
# Test loss :  0.2414136379957199
# Running for NN with 19 hidden neurons
# Train loss:  0.2604861259460449
# Test loss :  0.1973024308681488
